# %% [markdown]
# # Pandas Series 연습문제
#
# 데이터셋 **google_stock_price.csv** 와 **pokemon.csv** 를 사용하여 Pandas Series를 연습해보자
#
# 각 문제의 `?` 부분을 채워 코드를 완성하시오.

# %% [markdown]
# ## 1. 라이브러리 불러오기

# %%
import pandas as pd

# %% [markdown]
# ## 2. 데이터 불러오기

# %% [markdown]
# ### 문제 1
# `google_stock_price.csv` 파일을 불러와 `google` 변수에 저장.

# %%
google = ?

# %% [markdown]
# ### 문제 2
# `pokemon.csv` 파일을 불러와 `pokemon` 변수에 저장.

# %%
pokemon = ?

# %% [markdown]
# ### 문제 3
# pokemon 데이터에서 **Name 열만 선택하여 Series**로 만들고 `pokemon_name` 변수에 저장.

# %%
pokemon_name = ?

# %% [markdown]
# ## 3. 데이터 확인

# %% [markdown]
# ### 문제 4
# `google` 데이터의 **상위 10개 행**을 출력.

# %%
?

# %% [markdown]
# ### 문제 5
# `google` 데이터의 **마지막 5개 행**을 출력.

# %%
?

# %% [markdown]
# ### 문제 6
# `pokemon_name` Series의 **데이터 개수**를 구하기.

# %%
?

# %% [markdown]
# ### 문제 7
# `pokemon_name` Series의 **데이터 타입**을 확인.

# %%
?

# %% [markdown]
# ## 4. Series 변환

# %% [markdown]
# ### 문제 8
# `pokemon_name` Series를 **Python 리스트(list)** 로 변환.

# %%
?

# %% [markdown]
# ### 문제 9
# `google` 데이터에서 **Price 열만 추출하여 Series**로 만들고 `price_series` 변수에 저장.

# %%
price_series = ?

# %% [markdown]
# ## 5. 데이터 분석

# %% [markdown]
# ### 문제 10
# `price_series`에서 **최대값**과 **최소값** 구하기.

# %%
?

# %% [markdown]
# ### 문제 11
# `price_series`의 **앞의 20개 값**을 `first_20_price` 변수에 저장.

# %%
first_20_price = ?

# %% [markdown]
# ### 문제 12
# pokemon 데이터에서:
# 1. `Type` 열을 Series로 추출
# 2. 상위 15개 값을 출력.

# %%
?

# %% [markdown]
# ## 6. 심화 문제

# %% [markdown]
# ### 문제 13
# `price_series`의 **평균(mean)** 과 **중앙값(median)** 구하기.

# %%
?

# %% [markdown]
# ### 문제 14
# `pokemon_name` Series에서 **첫 번째 포켓몬 이름**과 **마지막 포켓몬 이름**을 출력.

# %%
?

# %% [markdown]
# # 문제 15
#
# pokemon_name Series에서 인덱스 0이 존재하는지 in 연산자를 사용하여 확인하라.

# %%
?

# %% [markdown]
# # 문제 16
#
# pokemon_name Series에서 "Bulbasaur"가 Series 값에 존재하는지 .values를 사용하여 확인하라.

# %%
?

# %% [markdown]
# # 문제 17
#
# pokemon_name Series에서 "Bulbasaur"가 존재하는지 .isin()을 사용하여 확인하라.

# %%
?

# %% [markdown]
# # 문제 18
#
# price_series를 오름차순으로 정렬하라.

# %%
?

# %% [markdown]
# # 문제 19
#
# price_series를 내림차순으로 정렬하라.

# %%
?

# %% [markdown]
# # 문제 20
#
# price_series를 내림차순으로 정렬한 뒤 상위 5개 값을 출력하라.

# %%
?

# %% [markdown]
# # 문제 21.
# 존재하지 않는 인덱스 2000을 조회하고, 값이 없을 경우 "Not Found" 를 반환하라.

# %%
?

# %% [markdown]
# # 문제 21 (Google 데이터)
#
# price_series를 이용하여 Google 주가 변화를 matplotlib pyplot으로 선 그래프로 시각화하라.
#
# 조건
#
# 	*	matplotlib.pyplot 사용
# 	*	x축은 인덱스
# 	*	y축은 가격

# %%
?

# %% [markdown]
# # 문제 22 (Pokemon 데이터)
#
# pokemon_name Series에서 앞의 10개 포켓몬 이름 길이를 계산한 뒤 pyplot으로 막대그래프를 그리라.
#
# 조건
#
# 	*	이름 길이 사용
# 	*	막대그래프(bar chart)

# %%
?
